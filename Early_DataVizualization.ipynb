# %% [markdown]
# <a href="https://colab.research.google.com/github/racoci/clusters-MO433/blob/main/Early_DataVizualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://www.ic.unicamp.br/~wainer/cursos/2s2021/433/ex2-data.csv"
df = pd.read_csv(url, sep="\s+", header=None)
df
# Out:
#         0      1      2      3      4   ...     8      9     10     11    12
# 0   -10.63  -3.91  27.69   2.32  -8.17  ...  -5.62   7.98  5.32   1.35 -4.56
# 1    12.56 -19.50   4.39   1.53  -3.55  ...   5.72   1.58 -3.41  -1.85  2.55
# 2     4.19 -12.30 -22.25  -6.14   7.47  ... -10.22   8.19  5.50  11.08 -2.19
# 3    -6.38 -18.36  -6.67  -1.42  -3.67  ...  -3.01  -4.39 -3.40  -1.06  8.25
# 4   -16.33   0.41   1.56 -10.51   9.37  ...  -6.41  -8.93 -8.05   3.81  2.76
# ..     ...    ...    ...    ...    ...  ...    ...    ...   ...    ...   ...
# 995  16.61 -14.12  -0.55   3.00  12.30  ...  10.13  -5.37 -8.28 -10.78  2.00
# 996 -30.76  10.46  -1.95  -6.10  -1.55  ...  -3.93  -1.74 -7.33  -4.93 -3.53
# 997   9.61 -21.71  10.19  -8.49 -10.63  ...  -2.23   5.86 -2.00   2.94  7.31
# 998 -14.32  -4.46  -4.53  -7.15   2.38  ...  -0.81 -13.97 -3.52  -1.13  5.46
# 999  17.40  11.46  14.03   5.07   0.81  ...  -0.34   1.59 -3.86  -4.54  3.02
#
# [1000 rows x 13 columns]

# %%
df.to_csv("ex2-data.csv")

# %%
import numpy as np
from sklearn.decomposition import PCA
pca = PCA(n_components=4)
pca.fit(df.transpose())
pca.components_.shape
# Out:
# (4, 1000)

# %%
pca_df = pd.DataFrame(pca.components_.T)
pca_df
# Out:
#             0         1         2         3
# 0   -0.024889 -0.043149  0.062848  0.029569
# 1    0.047261 -0.031993  0.009160  0.017270
# 2    0.025965 -0.002059 -0.064484 -0.049175
# 3    0.007258 -0.035764 -0.031139 -0.016181
# 4   -0.033027 -0.007607  0.009691 -0.028973
# ..        ...       ...       ...       ...
# 995  0.049234 -0.017921 -0.008499  0.000987
# 996 -0.074341  0.003118 -0.004798 -0.021164
# 997  0.042531 -0.042769  0.027349 -0.011275
# 998 -0.022423 -0.010487 -0.009287 -0.019497
# 999  0.018517  0.015912  0.035992  0.013338
#
# [1000 rows x 4 columns]

# %%
import plotly.express as px
fig = px.scatter_3d(pca_df, x=0, y=1, z=2, color=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a172a8a7-118e-4d77-ac1b-a4e619493ff1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a172a8a7-118e-4d77-ac1b-a4e619493ff1")) {
#                     Plotly.newPlot(
#                         'a172a8a7-118e-4d77-ac1b-a4e619493ff1',
# ...

# %%
from sklearn.manifold import TSNE
df_array = df.to_numpy()
tsne = TSNE(n_components=3).fit_transform(df_array)
tsne.shape
# Out:
# (1000, 3)

# %%
tsne_df = pd.DataFrame(simplified)
fig = px.scatter_3d(tsne_df, x=0, y=1, z=2)
fig.write_html("3D-t-SNE.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3eaf207f-15fc-4ea3-939a-faeb30bc470a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3eaf207f-15fc-4ea3-939a-faeb30bc470a")) {
#                     Plotly.newPlot(
#                         '3eaf207f-15fc-4ea3-939a-faeb30bc470a',
# ...

# %%
fig = px.scatter(sdd, x=0, y=1, color=2)
fig.write_html("2D-t-SNE.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e08e4442-1c31-4a63-b6bd-4cd8c27a2ac3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e08e4442-1c31-4a63-b6bd-4cd8c27a2ac3")) {
#                     Plotly.newPlot(
#                         'e08e4442-1c31-4a63-b6bd-4cd8c27a2ac3',
# ...
